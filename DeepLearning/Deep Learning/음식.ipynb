# %%
import pandas as pd

# %%
eat = pd.read_csv('eat.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-024d85ef58bc> in <cell line: 1>()
# ----> 1 eat = pd.read_csv('eat.csv', encoding='cp949')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
eat.nunique()
# Out:
# name          29810
# method           14
# why              13
# category         17
# ingredient    94400
# quantity          6
# level             5
# time              8
# dtype: int64

# %%
eat.category.unique()
# Out:
# array(['디저트', '밑반찬', '밥/죽/떡', '메인반찬', '면/만두', '빵', '양념/소스/잼', '양식', '스프',
#        '과자', '차/음료/술', '찌개', '국/탕', '샐러드', '퓨전', '김치/젓갈/장류', '기타'],
#       dtype=object)

# %%
eat.method.unique()
# Out:
# array(['튀김', '부침', '굽기', '끓이기', '볶음', '기타', '조림', '찜', '무침', '절임', '비빔',
#        '데치기', '삶기', '회'], dtype=object)

# %%
eat.why.unique()
# Out:
# array(['간식', '일상', '술안주', '손님접대', '도시락', '영양식', '야식', '초스피드', '다이어트',
#        '명절', '기타', nan, '이유식', '해장'], dtype=object)

# %%
eat = eat[eat['category'].isin(['밑반찬', '밥/죽/떡', '메인반찬', '면/만두', '양식', '스프',  '찌개', '국/탕', '샐러드', '퓨전'])]

# %%
eat = eat[eat['why'].isin(['간식', '일상', '술안주', '손님접대', '도시락', '영양식', '야식', '다이어트', '해장'])]

# %%
eat = eat.drop('method',axis=1)

# %%
eat = eat.dropna()

# %%
eat.head()
# Out:
#       name   why category                                         ingredient  \
# 3    현미호두죽    일상    밥/죽/떡           [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간
# 4     북어갈비   술안주     메인반찬  [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...
# 5  토마토스파게티    일상     면/만두  [재료] 파스타면 [양념] 토마토 1개| 토마토 페이스트 3T| 양파 1/2개| 다...
# 6   표고버섯탕수  손님접대     메인반찬  [재료] 건표고버섯 9개| 오이 1/2개| 당근 1/2개| 양파 1/2개| 사과 1...
# 7     갈릭치킨  손님접대     메인반찬  [재료] 닭 1마리 [닭양념] 통마늘 3개| 다진마늘 1T| 화이트와인또는우유| 올...
#
#   quantity level   time
# 3      2인분    초급  30분이내
# 4      2인분    초급  60분이내
# 5      1인분    초급  30분이내
# 6      2인분    초급  30분이내
# 7      2인분    중급  60분이내

# %%
eat.quantity.unique()
# Out:
# array(['2인분', '1인분', '3인분', '4인분', '6인분이상', '5인분'], dtype=object)

# %%
eat.level.unique()
# Out:
# array(['초급', '중급', '아무나', '고급', '신의경지'], dtype=object)

# %%
eat.time.unique()
# Out:
# array(['30분이내', '60분이내', '90분이내', '10분이내', '15분이내', '2시간이상', '2시간이내',
#        '5분이내'], dtype=object)

# %%
eat.to_csv('eat.csv',index=False)

# %%
eat = eat.head(50)
eat
# Out:
#               name   why category  \
# 3            현미호두죽    일상    밥/죽/떡
# 4             북어갈비   술안주     메인반찬
# 5          토마토스파게티    일상     면/만두
# 6           표고버섯탕수  손님접대     메인반찬
# 7             갈릭치킨  손님접대     메인반찬
# 9           참치삼각김밥   도시락    밥/죽/떡
# 10        뚝배기해물떡볶이   술안주    밥/죽/떡
# 12         참치깻잎주먹밥   도시락    밥/죽/떡
# 14            스팸쌈밥   도시락    밥/죽/떡
# 15        베이컨김치말이밥   도시락    밥/죽/떡
# 18         오징어볶음우동    일상     면/만두
# 20        카레새우삼각김밥   도시락    밥/죽/떡
# 23          고구마그라탕    일상       양식
# 26            감자스프    일상       스프
# 27           뚝배기라면    야식     면/만두
# 29          오코노미야키   술안주     메인반찬
# 30            야끼만두    간식     면/만두
# 31            두부조림    일상      밑반찬
# 32           매운갈비찜    일상     메인반찬
# 33            어묵볶음    일상      밑반찬
# 36            꼬마김밥   도시락    밥/죽/떡
# 48   소고기크림치즈오븐스파게티    일상     면/만두
# 52        돼지고기김치찌개    일상       찌개
# 58              찜닭  손님접대     메인반찬
# 62             파스타    일상     면/만두
# 69            쏘야볶음   술안주     메인반찬
# ...

# %%
eat.reset_index(inplace=True)
eat
# Out:
#     index           name   why category  \
# 0       3          현미호두죽    일상    밥/죽/떡
# 1       4           북어갈비   술안주     메인반찬
# 2       5        토마토스파게티    일상     면/만두
# 3       6         표고버섯탕수  손님접대     메인반찬
# 4       7           갈릭치킨  손님접대     메인반찬
# 5       9         참치삼각김밥   도시락    밥/죽/떡
# 6      10       뚝배기해물떡볶이   술안주    밥/죽/떡
# 7      12        참치깻잎주먹밥   도시락    밥/죽/떡
# 8      14           스팸쌈밥   도시락    밥/죽/떡
# 9      15       베이컨김치말이밥   도시락    밥/죽/떡
# 10     18        오징어볶음우동    일상     면/만두
# 11     20       카레새우삼각김밥   도시락    밥/죽/떡
# 12     23         고구마그라탕    일상       양식
# 13     26           감자스프    일상       스프
# 14     27          뚝배기라면    야식     면/만두
# 15     29         오코노미야키   술안주     메인반찬
# 16     30           야끼만두    간식     면/만두
# 17     31           두부조림    일상      밑반찬
# 18     32          매운갈비찜    일상     메인반찬
# 19     33           어묵볶음    일상      밑반찬
# 20     36           꼬마김밥   도시락    밥/죽/떡
# 21     48  소고기크림치즈오븐스파게티    일상     면/만두
# ...

# %%
eat.ingredient
# Out:
# 0              [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간
# 1     [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...
# 2     [재료] 파스타면 [양념] 토마토 1개| 토마토 페이스트 3T| 양파 1/2개| 다...
# 3     [재료] 건표고버섯 9개| 오이 1/2개| 당근 1/2개| 양파 1/2개| 사과 1...
# 4     [재료] 닭 1마리 [닭양념] 통마늘 3개| 다진마늘 1T| 화이트와인또는우유| 올...
# 5     [재료] 밥 2공기| 참치캔 큰거 1개| 양파| 다진김치| 김밥용김 [양념] 고추장...
# 6     [재료] 떡볶이떡 150g| 당근 1/2개| 파 1뿌리| 양파 1/2개| 양배추 1...
# 7     [재료] 밥 2공기| 깻잎 10장| 참치 작은캔 1개| 당근1/2개| 조미 김10장...
# 8     [재료] 밥 2공기| 상추(작은걸로골라서)나그외쌈야채| 스팸| 밑반찬 [양념] 참기...
# 9        [재료] 밥 1공기| 김치 1/6포기| 베이컨 적당량 | 깻잎 5장| 양파 1/4개
# 10    [재료] 오징어 1마리| 양파 1/4개| 대파 1/2쪽| 당근 1/3개| 청고추 1...
# 11    [재료] 새우 7마리| 양파 1/4개| 김치 1/6포기| 밥지을쌀| 김밥용김| 계란...
# 12    [재료] 고구마 으깬것 250g| 생크림 2큰술| 설탕 1큰술| 버터 1큰술| 아몬...
# 13    [재료] 감자(中) 2개| 생크림 1C| 우유 1C| 양파 1/2개| 베이컨 2장|...
# 14    [재료] 좋아하는 종류의 라면 1봉지| 김치 1/4포기| 굴 5~6개| 파 1개| ...
# 15    [재료] 양배추 1/2통| 숙주 1줌| 오징어 1마리| 새우 6마리| 베이컨 2줄|...
# 16    [재료] 당면 2줌| 부추 1줌| 만두피 10장 [양념] 간장 2T| 물엿 또는 설...
# ...

# %%
eat = eat.drop('index', axis=1)

# %%
eat
# Out:
#              name   why category  \
# 0           현미호두죽    일상    밥/죽/떡
# 1            북어갈비   술안주     메인반찬
# 2         토마토스파게티    일상     면/만두
# 3          표고버섯탕수  손님접대     메인반찬
# 4            갈릭치킨  손님접대     메인반찬
# 5          참치삼각김밥   도시락    밥/죽/떡
# 6        뚝배기해물떡볶이   술안주    밥/죽/떡
# 7         참치깻잎주먹밥   도시락    밥/죽/떡
# 8            스팸쌈밥   도시락    밥/죽/떡
# 9        베이컨김치말이밥   도시락    밥/죽/떡
# 10        오징어볶음우동    일상     면/만두
# 11       카레새우삼각김밥   도시락    밥/죽/떡
# 12         고구마그라탕    일상       양식
# 13           감자스프    일상       스프
# 14          뚝배기라면    야식     면/만두
# 15         오코노미야키   술안주     메인반찬
# 16           야끼만두    간식     면/만두
# 17           두부조림    일상      밑반찬
# 18          매운갈비찜    일상     메인반찬
# 19           어묵볶음    일상      밑반찬
# 20           꼬마김밥   도시락    밥/죽/떡
# 21  소고기크림치즈오븐스파게티    일상     면/만두
# 22       돼지고기김치찌개    일상       찌개
# 23             찜닭  손님접대     메인반찬
# 24            파스타    일상     면/만두
# 25           쏘야볶음   술안주     메인반찬
# 26          짜장떡볶이    간식    밥/죽/떡
# ...

# %%
eat.to_excel('eat50.xlsx')

# %%
import random

spicy = [random.randint(1, 3) for _ in range(50)]
salt = [random.randint(1, 3) for _ in range(50)]

# %%
eat_sora = pd.read_csv('eat_new.csv', encoding='cp949')
eat_sora
# Out:
#         name  why category                                         ingredient  \
# 0    베이컨꼬마김밥  도시락    밥/죽/떡  밥 3공기, 김밥용어묵, 오이 1/2개, 캔햄이나김밥용햄, 김밥용단무지, 베이컨, ...
# 1     삼겹김치김밥   일상    밥/죽/떡  밥 3공기, 김밥용어묵, 오이 1/2개, 캔햄이나김밥용햄, 김밥용단무지, 당근, 삼...
# 2    스팸김치볶음밥   일상    밥/죽/떡  밥 1공기, 김치 1포기, 어묵 1장, 계란 1개, 스팸 1개, 파슬리 약간, 설탕...
# 3    삼겹김치볶음밥   일상    밥/죽/떡  밥 3공기, 김치 1포기, 어묵 1장, 계란 2개, 삼겹살 500g, 깻잎, 파슬리...
# 4      로제떡볶이   일상    밥/죽/떡  떡볶이떡 400g, 양파 1/2개, 양배추 1/8통,  베이컨, 우유 200ml, ...
# 5      로제파스타   일상     면/만두  앤젤헤어 파스타 2인분, 토마토소스 200ml, 생크림 200ml, 베이컨 2줄, ...
# 6   치즈오븐스파게티   간식     면/만두     체다치즈 1장, 스파게티 국수 4인분, 모짜렐라 치즈 적당량, 헤비위핑크림 150g
# 7    소고기스파게티   일상     면/만두                  소고기 50g, 스파게티 국수 2인분, 헤비위핑크림 150g
# 8    베이컨스파게티  도시락     면/만두  배추김치 50g, 베이컨 2줄, 체다치즈 1장, 스파게티 국수 1인분, 모짜렐라 치...
# 9       팥찹쌀떡   간식    밥/죽/떡        찹쌀가루(습식) 400g, 찬물 220g, 옥수수전분 적당량, 팥앙금 500g
# 10   딸기모찌찹쌀떡   간식    밥/죽/떡  찹쌀가루(습식) 400그램, 찬물 220그램, 딸기 5개, 옥수수전분 적당량, 팥앙...
# ...

# %%
eat = pd.concat([eat, eat_sora], axis=0)
eat
# Out:
#        name   why category                                         ingredient  \
# 0     현미호두죽    일상    밥/죽/떡           [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간
# 1      북어갈비   술안주     메인반찬  [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...
# 2   토마토스파게티    일상     면/만두  [재료] 파스타면 [양념] 토마토 1개| 토마토 페이스트 3T| 양파 1/2개| 다...
# 3    표고버섯탕수  손님접대     메인반찬  [재료] 건표고버섯 9개| 오이 1/2개| 당근 1/2개| 양파 1/2개| 사과 1...
# 4      갈릭치킨  손님접대     메인반찬  [재료] 닭 1마리 [닭양념] 통마늘 3개| 다진마늘 1T| 화이트와인또는우유| 올...
# ..      ...   ...      ...                                                ...
# 11     로제찜닭    일상     메인반찬  닭 중간크기 1마리, 청양고추 5개, 건고추 5개, 양파 1개, 감자 3개, 당면 ...
# 12    고구마스프    간식       스프  고구마(中) 2개, 생크림 1C, 우유 1C, 양파 1/2개, 베이컨 2장, 체다치...
# 13    골뱅이쫄면   술안주     면/만두  골뱅이, 소면 2인분, 양파 1/4개, 대파 1/2쪽, 당근 1/3개, 청고추 1개...
# 14     카레전골    일상     메인반찬  팽이버섯 2봉지, 당근 1/2개, 표고버섯 2개, 대파 1쪽, 물 3컵, 백세카레가...
# 15   참치김치찌개    일상       찌개  참치 1캔, 감자 중간크기 1개, 김치 1포기, 양파 1/2개, 두부 1모, 고추장...
#
# ...

# %%
eat_youngjae = pd.read_csv('eat3.csv', encoding='cp949')
eat = pd.concat([eat, eat_youngjae], axis=0)
eat
# Out:
#         name   why category  \
# 0      현미호두죽    일상    밥/죽/떡
# 1       북어갈비   술안주     메인반찬
# 2    토마토스파게티    일상     면/만두
# 3     표고버섯탕수  손님접대     메인반찬
# 4       갈릭치킨  손님접대     메인반찬
# ..       ...   ...      ...
# 11        치킨    일상     메인반찬
# 12   현미베이크치킨    안주     메인반찬
# 13    치즈갈릭치킨    안주     메인반찬
# 14    현미갈릭치킨    일상     메인반찬
# 15  뚝배기해물떡볶이   술안주    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개| 토마토 페이스트 3T| 양파 1/2개| 다...      1인분    초급  30분이내
# 3   [재료] 건표고버섯 9개| 오이 1/2개| 당근 1/2개| 양파 1/2개| 사과 1...      2인분    초급  30분이내
# 4   [재료] 닭 1마리 [닭양념] 통마늘 3개| 다진마늘 1T| 화이트와인또는우유| 올...      2인분    중급  60분이내
# ..                                                ...      ...   ...    ...
# 11                                  닭 1마리, 우유, 버터, 소금      1인분    초급  30분이내
# ...

# %%
ingredi = []
for i in eat['ingredient']:
  ingredi.append(i.replace("|", ","))

ingredi
# Out:
# ['[재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간',
#  '[재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T, 다진파 1T, 다진마늘 1T, 참기름 1T, 깨소금 1T, 후춧가루 약간',
#  '[재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다진마늘 1T, 피망 1/2개, 올리브유 3T',
#  '[재료] 건표고버섯 9개, 오이 1/2개, 당근 1/2개, 양파 1/2개, 사과 1/2쪽, 그외의 야채, 과일 [녹말물] 녹말가루 2C, 물 1C, 계란 노른자 1개 [탕수 소스] 물 2C, 설탕 1/2C, 식초 3T, 간장 1T, 녹말물 2T',
#  '[재료] 닭 1마리 [닭양념] 통마늘 3개, 다진마늘 1T, 화이트와인또는우유, 올리브유또는버터, 마늘솔트또는소금 [샐러드 드레싱] 파인애플 2쪽, 마요네즈 2T, 머스터드 1T, 식초1/2T(또는 레몬즙) , 꿀 1T',
#  '[재료] 밥 2공기, 참치캔 큰거 1개, 양파, 다진김치, 김밥용김 [양념] 고추장, 다진마늘, 참기름, 맛소금, 마요네즈',
#  '[재료] 떡볶이떡 150g, 당근 1/2개, 파 1뿌리, 양파 1/2개, 양배추 1/4통, 어묵 2장, 오징어, 새우, 조갯살, 홍합살 [양념장] 고춧가루 2T, 고추장 1T, 물엿 1T, 간장 1T, 참기름 1T, 다진 마늘 1/2T, 깨 1/2T, 후추가루 약간',
#  '[재료] 밥 2공기, 깻잎 10장, 참치 작은캔 1개, 당근1/2개, 조미 김10장 [양념] 다진 마늘1/4t개, 깨소금, 맛소금, 참기름',
#  '[재료] 밥 2공기, 상추(작은걸로골라서)나그외쌈야채, 스팸, 밑반찬 [양념] 참기름 1/2t, 맛소금 약간 , 깨 약간 ',
#  '[재료] 밥 1공기, 김치 1/6포기, 베이컨 적당량 , 깻잎 5장, 양파 1/4개',
# ...

# %%
eat['ingredient'] = ingredi
eat
# Out:
#         name   why category  \
# 0      현미호두죽    일상    밥/죽/떡
# 1       북어갈비   술안주     메인반찬
# 2    토마토스파게티    일상     면/만두
# 3     표고버섯탕수  손님접대     메인반찬
# 4       갈릭치킨  손님접대     메인반찬
# ..       ...   ...      ...
# 11        치킨    일상     메인반찬
# 12   현미베이크치킨    안주     메인반찬
# 13    치즈갈릭치킨    안주     메인반찬
# 14    현미갈릭치킨    일상     메인반찬
# 15  뚝배기해물떡볶이   술안주    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T,...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다...      1인분    초급  30분이내
# 3   [재료] 건표고버섯 9개, 오이 1/2개, 당근 1/2개, 양파 1/2개, 사과 1...      2인분    초급  30분이내
# 4   [재료] 닭 1마리 [닭양념] 통마늘 3개, 다진마늘 1T, 화이트와인또는우유, 올...      2인분    중급  60분이내
# ..                                                ...      ...   ...    ...
# 11                                  닭 1마리, 우유, 버터, 소금      1인분    초급  30분이내
# ...

# %%
eat.spicy[0:50] = spicy
eat
# Out:
# <ipython-input-38-224995c1a6ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eat.spicy[0:50] = spicy
#         name   why category  \
# 0      현미호두죽    일상    밥/죽/떡
# 1       북어갈비   술안주     메인반찬
# 2    토마토스파게티    일상     면/만두
# 3     표고버섯탕수  손님접대     메인반찬
# 4       갈릭치킨  손님접대     메인반찬
# ..       ...   ...      ...
# 11        치킨    일상     메인반찬
# 12   현미베이크치킨    안주     메인반찬
# 13    치즈갈릭치킨    안주     메인반찬
# 14    현미갈릭치킨    일상     메인반찬
# 15  뚝배기해물떡볶이   술안주    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T,...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다...      1인분    초급  30분이내
# ...

# %%
eat.salt[0:50] = salt
# Out:
# <ipython-input-39-efb99b0227aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eat.salt[0:50] = salt

# %%
eat
# Out:
#         name   why category  \
# 0      현미호두죽    일상    밥/죽/떡
# 1       북어갈비   술안주     메인반찬
# 2    토마토스파게티    일상     면/만두
# 3     표고버섯탕수  손님접대     메인반찬
# 4       갈릭치킨  손님접대     메인반찬
# ..       ...   ...      ...
# 11        치킨    일상     메인반찬
# 12   현미베이크치킨    안주     메인반찬
# 13    치즈갈릭치킨    안주     메인반찬
# 14    현미갈릭치킨    일상     메인반찬
# 15  뚝배기해물떡볶이   술안주    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T,...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다...      1인분    초급  30분이내
# 3   [재료] 건표고버섯 9개, 오이 1/2개, 당근 1/2개, 양파 1/2개, 사과 1...      2인분    초급  30분이내
# 4   [재료] 닭 1마리 [닭양념] 통마늘 3개, 다진마늘 1T, 화이트와인또는우유, 올...      2인분    중급  60분이내
# ..                                                ...      ...   ...    ...
# 11                                  닭 1마리, 우유, 버터, 소금      1인분    초급  30분이내
# ...

# %%
eat_dongmin = pd.read_csv('dongmin.csv', encoding='cp949')
eat_dongmin
# Out:
#          name why category                                         ingredient  \
# 0        참치라면  일상     면/만두  라면사리 1개, 참치, 새우 2마리, 오징어 1/4마리, 양파 1/2개, 당근 1/...
# 1        불닭라면  일상     면/만두  라면사리 1개, 새우 2마리, 오징어 1/4마리, 양파 1/2개, 당근 1/5개, ...
# 2      차돌박이라면  일상     면/만두  라면사리 1개, 차돌박이 고기180g, 참치, 새우 2마리, 오징어 1/4마리, 양...
# 3      돼지고기라면  일상     면/만두  라면사리 1개, 돼지고기 150g ,참치, 새우 2마리, 오징어 1/4마리, 양파 ...
# 4    돼지고기된장찌개  일상       일상  돼지고기 200g, 감자1개, 양파 1/2개, 두부 1/2모, 고추장, 된장, 물,...
# 5    참치돼지고기찌개  일상       일상  돼지고기 200g, 감자1개, 양파 1개, 두부 1모, 참치, 고추장, 된장, 물,...
# 6   순두부돼지고기찌개  일상       일상  돼지고기 200g, 감자1개, 양파 1/8개, 두부 1/3모, 고추장, 된장, 물,...
# 7      차돌박이찌개  일상       일상  차돌박이 고기 200g, 감자1개, 양파 1/3개, 두부 1/4모, 고추장, 된장,...
# 8    차돌박이된장찌개  일상       일상  차돌박이 고기 200g, 감자1개, 양파 1/4개, 두부 1/6모, 고추장, 된장,...
# 9    차돌박이김치찌개  일상       일상  차돌박이 고기 200g, 감자1개, 양파 1/5개, 두부 1/7모, 김치, 고추장,...
# 10    현미밥샌드위치  일상    밥/죽/떡  밥 1공기, 빵 4쪽, 김치, 애호박, 새송이버섯, 피망, 현미, 식용유, 마요네즈...
# ...

# %%
eat = pd.concat([eat, eat_dongmin], axis=0)
eat
# Out:
#         name   why category  \
# 0      현미호두죽    일상    밥/죽/떡
# 1       북어갈비   술안주     메인반찬
# 2    토마토스파게티    일상     면/만두
# 3     표고버섯탕수  손님접대     메인반찬
# 4       갈릭치킨  손님접대     메인반찬
# ..       ...   ...      ...
# 11    찹쌀샌드위치    일상    밥/죽/떡
# 12   오곡밥샌드위치    일상    밥/죽/떡
# 13   김치밥샌드위치    일상    밥/죽/떡
# 14    굴밥샌드위치    일상    밥/죽/떡
# 15  완두콩밥샌드위치    일상    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T,...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다...      1인분    초급  30분이내
# 3   [재료] 건표고버섯 9개, 오이 1/2개, 당근 1/2개, 양파 1/2개, 사과 1...      2인분    초급  30분이내
# 4   [재료] 닭 1마리 [닭양념] 통마늘 3개, 다진마늘 1T, 화이트와인또는우유, 올...      2인분    중급  60분이내
# ..                                                ...      ...   ...    ...
# 11  찹쌀 1공기, 빵 4쪽, 김치, 애호박, 새송이버섯, 피망, 식용유, 마요네즈, 고...      1인분    초급    30분
# ...

# %%
eat.reset_index(inplace=True)
eat
# Out:
#     index      name   why category  \
# 0       0     현미호두죽    일상    밥/죽/떡
# 1       1      북어갈비   술안주     메인반찬
# 2       2   토마토스파게티    일상     면/만두
# 3       3    표고버섯탕수  손님접대     메인반찬
# 4       4      갈릭치킨  손님접대     메인반찬
# ..    ...       ...   ...      ...
# 93     11    찹쌀샌드위치    일상    밥/죽/떡
# 94     12   오곡밥샌드위치    일상    밥/죽/떡
# 95     13   김치밥샌드위치    일상    밥/죽/떡
# 96     14    굴밥샌드위치    일상    밥/죽/떡
# 97     15  완두콩밥샌드위치    일상    밥/죽/떡
#
#                                            ingredient quantity level   time  \
# 0            [재료] 현미 4컵, 찹쌀 2컵, 호두 50g, 물 1/2컵, 소금 약간      2인분    초급  30분이내
# 1   [재료] 북어포 1마리, 찹쌀가루 1C [양념] 간장 2T, 설탕 1T, 물 1T,...      2인분    초급  60분이내
# 2   [재료] 파스타면 [양념] 토마토 1개, 토마토 페이스트 3T, 양파 1/2개, 다...      1인분    초급  30분이내
# 3   [재료] 건표고버섯 9개, 오이 1/2개, 당근 1/2개, 양파 1/2개, 사과 1...      2인분    초급  30분이내
# 4   [재료] 닭 1마리 [닭양념] 통마늘 3개, 다진마늘 1T, 화이트와인또는우유, 올...      2인분    중급  60분이내
# ..                                                ...      ...   ...    ...
# ...

# %%
eat.to_csv('eat_final.csv', encoding='cp949', index=False)
