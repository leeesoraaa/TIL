# %% [markdown]
# # 지도학습(Supervised Learning)
# - 지도학습이란 컴퓨터(알고리즘)에 훈련 데이터(train data)와 레이블(Label)을 포함시켜 학습을 하는 방법이다.
# - 여기서 훈련 데이터는 입력 데이터(input data)가 되며, 레이블은 정답(label data)가 된다.
# - 즉, 훈련 데이터로부터 하나의 함수를 유추해내기 위한 기계학습의 한 방법이다.
# - 지도 학습의 훈련 데이터(train data)는 일반적으로 입력 데이터(input data)에 대한 속성을 벡터 형태로 포함하고 있으며, 각각의 벡터에 대해 원하는 결과가 무엇인지 표시되어 있다.
# - 지도 학습에는 크게 회귀 분석(Regressioon)과 분류(Classification)등이 있다.

# %% [markdown]
# ## 회귀 분석(Regression)
# - 입력값: 연속값(실수값), 이산값(범주형, 명목형) 등 모든 데이터
# - 출력값: 연속값(실수형)
# - 모델 형태: 일반적인 함수 형태(y = w_1x + w_2, y = ax + b)
# - 회귀 분석은 연속형 변수들에 대해 두 변수 사이의 모형을 구한 뒤 적합도를 측정해 내는 분석 방법
# - 회귀 분석은 크게 선형(Linear)과 비선형(Non-Linear)로 나눌 수 있다.

# %% [markdown]
# ## 분류(Classification)
# - 입력값: 연속값(실수형), 이산값(범주형) 등 모두 가능
# - 출력값: 이산값(범주형)
# - 모델 형태: 이진 분류라면 시그모이드(sigmode)함수, 다중분류라면 소프트 맥스(softmax) 함수 필요

# %% [markdown]
# ## 데이터의 구성
# - 데이터는 피처(feature)와 라벨로 구성된다.
# - 이는 독립변수와 종속변수라고도 불린다.
# - 라벨은 y로 표기하며, 라벨의 유무에 따라 지도학습, 비지도학습으로 구분된다.

# %% [markdown]
# ### Feature(=attribute, 피처, 속성, 특성)
# - 데이터 X의 특징, 혹은 항목을 의미

# %% [markdown]
# ### Parameter(파라미터, 가중치)
# - 주어진 데이터(입력값)말고, 모델이 가지고 있는 학습 가능한(learnable) 파라미터

# %% [markdown]
# ### Hyperparameter(하이퍼파라미터)
# - 모델 학습에 있어 인간이 정해야 하는 변수들
# - 학습률, 배치 크기 등등

# %% [markdown]
# ### Input(입력값) vs Output(출력값)
# - Input: 모델(함수)에 입력되는 값으로 데이터의 피처 부분(X로 표기)
# - Output: 모델로부터 출력되는 예측값(y로 표기)
