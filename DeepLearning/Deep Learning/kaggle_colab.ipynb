# %%
# !pip install kaggle

# %% [markdown]
# ## Kaggle API token file upload

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2c1ab2c8-3e0c-4f9d-a0de-31ee0f53707f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c1ab2c8-3e0c-4f9d-a0de-31ee0f53707f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Kaggle 사용을 위해 파일을 원하는 폴더로 옮기고 권한을 부여하는 작업

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/*

# %% [markdown]
# ## kaggle 진행중인 대회 리스트 추출

# %%
# !kaggle competitions list
# Out:
# ref                                                                               deadline             category            reward  teamCount  userHasEntered
# --------------------------------------------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# https://www.kaggle.com/competitions/llm-detect-ai-generated-text                  2024-01-22 23:59:00  Featured          $110,000       2699           False
# https://www.kaggle.com/competitions/optiver-trading-at-the-close                  2023-12-20 23:59:00  Featured          $100,000       4322           False
# https://www.kaggle.com/competitions/nfl-big-data-bowl-2024                        2024-01-08 23:59:00  Analytics         $100,000          0           False
# https://www.kaggle.com/competitions/blood-vessel-segmentation                     2024-02-06 23:59:00  Research           $80,000        320           False
# ...

# %% [markdown]
# ## Titanic 데이터를 가져오는 작업

# %%
# google driver와 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 작업 폴더 이동
import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/titanic_data')

# %%
# 현재 작업 폴더 확인(리눅스 명령)
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/titanic_data

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 4.07MB/s]

# %%
# 압축파일 해제
# !unzip -qq '/content/gdrive/MyDrive/Colab Notebooks/titanic_data/titanic.zip' -d '/content/gdrive/MyDrive/Colab Notebooks/titanic_data'

# %% [markdown]
# ## Titanic 데이터 분석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 현재 구글드라이브 경로 확인
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/titanic_data

# %%
# 디렉토리 이동시 cd '이동할 경로'
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
